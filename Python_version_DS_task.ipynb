# %%
import pandas as pd

# %%
survey_file1= pd.read_csv("C:\\Users\\Hp\\Documents\\salary_survey-1.csv")
survey_file2= pd.read_csv("C:\\Users\\Hp\\Documents\\salary_survey-2.csv")
survey_file3= pd.read_csv("C:\\Users\\Hp\\Documents\\salary_survey-3.csv")

# %%
print(type(survey_file1))
print(type(survey_file2))

print(survey_file1)
print(survey_file2)
print(survey_file3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#                  Timestamp How old are you? What industry do you work in?  \
# 0       4/24/2019 11:43:21            35-44                    Government
# 1       4/24/2019 11:43:26            25-34       Environmental nonprofit
# 2       4/24/2019 11:43:27            18-24               Market Research
# 3       4/24/2019 11:43:27            25-34                 Biotechnology
# 4       4/24/2019 11:43:29            25-34                    Healthcare
# ...                    ...              ...                           ...
# 34369   12/23/2020 8:47:19            45-54                      Military
# 34370  12/23/2020 12:21:14            45-54                    Healthcare
# 34371  12/25/2020 10:52:24            45-54                        Pharma
# 34372  12/26/2020 20:07:18            45-54                 Governamental
# 34373  12/29/2020 22:59:02            25-34                   Health Tech
#
# ...

# %%
survey_file1.describe()
survey_file2.describe()
survey_file3.describe()

survey_file1.head()
survey_file2.describe()
survey_file3.describe()
# Out:
#                  Timestamp Employer       Location          Job Title  \
# count                 3777     2004           3259               3776
# unique                3577     1338           1074               1388
# top     3/21/2016 14:19:33   Google  San Francisco  Software Engineer
# freq                     4       73            207                575
#
#        Years at Employer Years of Experience Annual Base Pay Signing Bonus  \
# count               3396                3442            3776          2496
# unique                71                  74            1067           202
# top                    1                   5          100000             0
# freq                1034                 360             101          1672
#
#        Annual Bonus Annual Stock Value/Bonus Gender Additional Comments
# count          2661                     2238   3587                 528
# unique          406                      346     31                 509
# ...

# %%
survey_file1.rename(columns = {'Job title':'Title'}, inplace = True)
survey_file1.rename(columns = {'Where are you located? (City/state/country)':'Location'}, inplace = True)
survey_file1.rename(columns = {'What is your annual salary?':'Salary'}, inplace = True)
survey_file1.rename(columns = {'How many years of post-college professional work experience do you have?':'Years experience'}, inplace = True)
survey_file1.rename(columns = {'Please indicate the currency':'Currency'}, inplace = True)
